# %% [markdown]
# ##  作業提醒
# 1. 繳交作業的檔名請用**中文姓名** :
# > HW1_self_introduction_陳韋伶.ipynb
# >
# > HW2_python_basics_陳韋伶.ipynb
#
# 2. 答案一定要 `print` 出來才會計分！

# %% [markdown]
# ## 題目一 （30％）
#
# ### 題目敘述
#
# 老師想要了解學生的成績狀況並給出評論，請你根據老師要求的條件完成以下程式。
#
# ### 程式要求
#
# 1: 創建字典
# - 首先，創建一個包含學生姓名作為鍵，成績列表作為值的字典 `grades`。在字典中，每個學生都有一個相對應的成績列表（已提供）。
#
# 2: 使用 `for` 迴圈遍歷字典
# - 接下來，使用 `for` 迴圈遍歷 `grades` 字典中的每一對鍵值對，其中鍵是學生姓名，值是成績列表。
#
# 3: 計算成績統計資訊並列印
# - 在迴圈中，執行以下操作：
#     - 計算學生的最低分數（最小值）：使用 `min()` 函數。
#     - 計算學生的最高分數（最大值）：使用 `max()` 函數。
#     - 計算學生的平均分數（整除）：使用 `sum()` 函數和 `len()` 函數。
#     - 列印學生的姓名和成績。
#     - 列印最高分數、最低分數和平均分數。
#
# 4: 根據平均分數列印評論
# - 接下來，在迴圈中使用 `if-elif-else` 條件來根據平均分數列印評論：
#     - 如果平均分數大於100，列印 "評論：你的成績有問題"。
#     - 如果平均分數等於100，列印 "評論：滿分"。
#     - 如果平均分數大於等於90，列印 "評論：優等"。
#     - 如果平均分數大於等於60，列印 "評論：及格"。
#     - 否則，列印 "評論：加油"。
#
# 5: 添加分隔線並完成迴圈
#   - 最後，在每次學生的資訊列印完畢後，使用 `print('====')` 添加分隔線以區分不同學生的資訊。

# %%
grades = {
    "Richard": [60, 0, 45, -1],
    "Una": [100, 99, 101, 100],
    "Linda": [99, 100, 99, 100],
    "Shu-Kai": [1000, 1000, 1000, 1000]
}

# %% [markdown]
# ## 題目二 (30%)
#
# ### 題目敘述
#
# 學校發現有校外人士濫用TA休息室，於是校方購入了新的機器保鏢，你需要設定一個程式來判斷哪些人可以進入休息室。
#
# 休息室很先進所以很多人想要進去瞧瞧，但是休息室有一些規則：
#
# - 如果是TA，則可以進入TA休息室。
#
# - 但是休息室很小，所以人數不能超過4個人，否則會引起騷亂。
#
# - VIP特權很大，所以他們會去另外的祕密休息室。
#
# 根據以上的條件，請你幫忙完成以下程式。
#
# ### 程式要求
#
#
# 1. 創建列表
#     - 首先，創建三個不同的列表：`ta_list`（TA 列表）、`vip_list`（VIP 列表）和 `people`（各種想要去休息室的人），這些列表將包含不同的姓名數據（已提供）。
# 2. 創建空列表和變數
#     - 接下來，創建兩個空列表 `ta_lounge` 和 `secret_lounge`，以及一個整數變數 `max_people` 並設值為 4。
# 3. 使用 for 迴圈進行篩選和分配
#     - 使用 for 迴圈來遍歷 `people` 列表中的每個姓名，並根據一些條件進行篩選和分配：
#       - 如果姓名在 `ta_list` 列表中，則將該姓名添加到 `ta_lounge`。
#       - 如果姓名在 `vip_list` 中，則將該姓名添加到 `secret_lounge`。
#       - 如果 `ta_lounge` 中的人數達到 `max_people`，則退出迴圈。
# 4. 列印結果
#    - 最後，請使用 `print()` 函數來列印 `ta_lounge` 和 `secret_lounge` 的內容。
#      - `print("TA Lounge:", ta_lounge)`
#      - `print("Secret Lounge:", secret_lounge)`

# %%
ta_list = ["Richard", "Una", "Linda", "Amy", "Joanne", "Mia", "Irene", "Amber"]
vip_list = ["Shu-Kai"]
people = ["Bob", "Alice", "Richard", "Bruce", "Shu-Kai", "Amy", "Una", "Eva", "Edward", "Joanne", "Linda", "Mia", "Irene", "Amber"]

# %% [markdown]
# ## 題目三（40％）
#
# ### 題目敘述
#
# 同第二題，你需要設定這些機器保鏢，但是學校主任比較龜毛，他多了幾個要求：
#
# - 如果是TA，則可以進入TA休息室 （`ta_lounge`）。
#
# - 但是休息室很小，所以人數不能超過4個人，否則會引起騷亂。
#
# - 主任覺得姓名長度超過6個英文字母的人很奇怪，所以他們不能進入休息室。
#
# - 主任也覺得用while loop很酷，所以你必須使用while loop。
#
# - VIP特權很大，所以他們會去另外的祕密休息室。
#
# 根據以上的條件，請你幫忙完成以下程式。
#
# ### 程式要求
#
# 1. 創建列表：
#    - 首先，創建幾個不同的列表，包括 `ta_list`、`vip_list` 和 `people`，這些列表將包含不同的姓名數據（已提供）。
# 2. 創建空列表和變數：
#    - 接下來，創建兩個空列表 `ta_lounge` 和 `secret_lounge`。
#    - 定義一個變數 `max_people` 並將值設為4，表示TA休息室的最大容納人數。
#    - 定義一個變數 `idx` 來迭代遍歷 `people` 列表中的姓名。
# 3. 使用迴圈進行篩選和分配：
#    - 使用 while 迴圈來遍歷 `people` 列表中的姓名，同時根據一些條件進行篩選和分配：
#      - 如果姓名不在 `ta_list` 和 `vip_list` 中，則跳過該姓名，繼續下一個。
#      - 如果姓名的長度大於6個字符，則跳過該姓名，繼續下一個。
#      - 如果 `ta_lounge` 存放的人數，還未達到最大容納人數(4)，則可以讓TA進去。
#      - 如果是VIP，則將該姓名添加到 `secret_lounge`。
#      - 記得每次迴圈迭代後，要增加 `idx` 以避免無限迴圈。
# 4. 列印結果
#    - 最後，請使用 `print()` 函數來列印 `ta_lounge` 和 `secret_lounge` 的內容。
#      - `print("TA Lounge:", ta_lounge)`
#      - `print("Secret Lounge:", secret_lounge)`

# %%
ta_list = ["Richard", "Una", "Linda", "Amy", "Joanne", "Mia", "Irene", "Amber"]
vip_list = ["Shu-Kai"]
people = ["Bob", "Alice", "Richard", "Bruce", "Amy", "Una", "Eva", "Edward", "Joanne", "Linda", "Shu-Kai", "Mia", "Irene", "Amber"]

# %% [markdown]
# ## 加分題（10％）
#
# 主管發現你題目二有一個大錯誤，如果不修正的話，他可能就沒有工作了。
#
# 現在的程式中的`ta_lounge` 一達到 `max_people` 就會退出迴圈 `people`，問題是還有 VIP 等著進去 `secret_lounge`。
#
#
# 請修改題目二中的程式碼，以確保在退出迴圈之前，所有 VIP 都有被考慮到（都有被遍歷到）。
#
# - 提示 1: 使用 `set()`
# - 提示 2: 行程式碼有兩個地方需要修改

# %%
ta = ["Richard", "Una", "Linda", "Amy", "Joanne", "Mia", "Irene", "Amber"]
vip_list = ["Shu-Kai", "Wen-Chang Chen", "Ing-Wen Tsai"]
people = ["Bob", "Alice", "Richard", "Bruce", "Shu-Kai", "Amy", "Ing-Wen Tsai", "Una", "Eva", "Edward", "Joanne", "Linda", "Mia", "Irene", "Amber", "Wen-Chang Chen"]
